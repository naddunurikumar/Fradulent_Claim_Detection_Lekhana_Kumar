# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv('insurance_claims.csv')

# %%
# Check at the first few entries
df.head(4)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
#
# [4 rows x 40 columns]

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (1000, 40)

# %%
df.info
# Out:
# <bound method DataFrame.info of      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]>

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values- _c39
inp1 = df.drop(columns=['_c39'])
inp1['authorities_contacted'].fillna('Unknown', inplace=True)
inp1.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values

for col in inp1.columns:
    print(f"{col}: {inp1[col].nunique()} unique values")
# Out:
# months_as_customer: 391 unique values
# age: 46 unique values
# policy_number: 1000 unique values
# policy_bind_date: 951 unique values
# policy_state: 3 unique values
# policy_csl: 3 unique values
# policy_deductable: 3 unique values
# policy_annual_premium: 991 unique values
# umbrella_limit: 11 unique values
# insured_zip: 995 unique values
# insured_sex: 2 unique values
# insured_education_level: 7 unique values
# insured_occupation: 14 unique values
# insured_hobbies: 20 unique values
# insured_relationship: 6 unique values
# capital-gains: 338 unique values
# capital-loss: 354 unique values
# incident_date: 60 unique values
# incident_type: 4 unique values
# collision_type: 4 unique values
# incident_severity: 4 unique values
# authorities_contacted: 5 unique values
# incident_state: 7 unique values
# incident_city: 7 unique values
# incident_location: 1000 unique values
# incident_hour_of_the_day: 24 unique values
# number_of_vehicles_involved: 4 unique values
# property_damage: 3 unique values
# bodily_injuries: 3 unique values
# witnesses: 4 unique values
# police_report_available: 3 unique values
# total_claim_amount: 763 unique values
# injury_claim: 638 unique values
# property_claim: 626 unique values
# vehicle_claim: 726 unique values
# auto_make: 14 unique values
# auto_model: 39 unique values
# auto_year: 21 unique values
# fraud_reported: 2 unique values

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
inp1.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# witnesses                      0
# police_report_available        0
# total_claim_amount             0
# injury_claim                   0
# property_claim                 0
# vehicle_claim                  0
# auto_make                      0
# auto_model                     0
# auto_year                      0
# fraud_reported                 0
# dtype: int64

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values

positive_columns = ['age', 'total_claim_amount', 'policy_annual_premium', 'umbrella_limit', 'capital-gains', 'capital-loss']

# Drop rows with negative values in these columns
inp1 = inp1[(inp1[positive_columns] >= 0).all(axis=1)]

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
columns_to_remove = ['policy_number', 'insured_zip'] + [col for col in inp1.columns if inp1[col].nunique() == 1]

# Drop identified columns
inp1.drop(columns=columns_to_remove, inplace=True)

# %%
# Check the dataset
print(inp1.columns)
# Out:
# Index(['months_as_customer', 'age', 'policy_bind_date', 'policy_state',
#        'policy_csl', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_sex', 'insured_education_level',
#        'insured_occupation', 'insured_hobbies', 'insured_relationship',
#        'capital-gains', 'incident_date', 'incident_type', 'collision_type',
#        'incident_severity', 'authorities_contacted', 'incident_state',
#        'incident_city', 'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
#inp1.dtypes

date_cols = ['policy_bind_date', 'incident_date']

for col in date_cols:
    if col in inp1.columns and inp1[col].dtype == 'object':
        inp1[col] = pd.to_datetime(inp1[col], errors='coerce')  # invalid dates become NaT

print(inp1[date_cols].dtypes)
# Out:
# policy_bind_date    datetime64[ns]
# incident_date       datetime64[ns]
# dtype: object

# %%
# Check the features of the data again
inp1.dtypes
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_bind_date               datetime64[ns]
# policy_state                           object
# policy_csl                             object
# policy_deductable                       int64
# policy_annual_premium                 float64
# umbrella_limit                          int64
# insured_sex                            object
# insured_education_level                object
# insured_occupation                     object
# insured_hobbies                        object
# insured_relationship                   object
# capital-gains                           int64
# incident_date                  datetime64[ns]
# incident_type                          object
# collision_type                         object
# incident_severity                      object
# authorities_contacted                  object
# incident_state                         object
# incident_city                          object
# incident_location                      object
# incident_hour_of_the_day                int64
# number_of_vehicles_involved             int64
# property_damage                        object
# bodily_injuries                         int64
# witnesses                               int64
# police_report_available                object
# total_claim_amount                      int64
# injury_claim                            int64
# property_claim                          int64
# vehicle_claim                           int64
# auto_make                              object
# auto_model                             object
# auto_year                               int64
# fraud_reported                         object
# dtype: object

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X = inp1.drop(columns='fraud_reported')
# Put the target variable in y
inp1['fraud_reported'] = inp1['fraud_reported'].astype(str).str.strip().str.upper()
# Step 2: Replace 'YES'/'NO' with 1/0
inp1['fraud_reported'] = inp1['fraud_reported'].map({'Y': 1, 'N': 0})

y= inp1['fraud_reported']

#X.info()
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 5    1
# 7    0
# Name: fraud_reported, dtype: int64

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Reset index for all train and test sets
X_train.reset_index(drop=True, inplace=True)
X_val.reset_index(drop=True, inplace=True)
y_train.reset_index(drop=True, inplace=True)
y_val.reset_index(drop=True, inplace=True)

# Check the shapes to ensure they match
print(X_train.shape)  # Should match y_train
print(y_train.shape)
# Out:
# (331, 35)
# (331,)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
X_train[numerical_cols].head()
# Out:
#    months_as_customer  age  policy_deductable  policy_annual_premium  \
# 0                 472   64                500                 989.24
# 1                  43   43                500                1320.39
# 2                 207   42               2000                1322.78
# 3                 256   39               1000                1351.10
# 4                 140   31                500                 708.64
#
#    umbrella_limit  capital-gains  incident_hour_of_the_day  \
# 0               0              0                        13
# 1               0              0                        16
# 2               0          55200                         9
# 3               0              0                        19
# 4         6000000          53500                         9
#
#    number_of_vehicles_involved  bodily_injuries  witnesses  \
# 0                            1                2          3
# 1                            1                2          1
# 2                            1                0          1
# 3                            3                0          2
# 4                            1                0          2
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_year
# 0               70900         14180            7090          49630       2002
# 1               79970          7270           21810          50890       1996
# 2                5900           590             590           4720       2007
# 3               64100          6410            6410          51280       2003
# 4               77880         14160            7080          56640       2015

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution

X_train[numerical_cols].hist(figsize=(20, 15), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
numerical_data = X_train[numerical_cols]

# Create correlation matrix
corr_matrix = numerical_data.corr()

# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
Y = y
plt.figure(figsize=(6, 4))
sns.countplot(x=Y, palette='Set2')
plt.title('Class Balance in Target Variable')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
# Get categorical columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns

def target_likelihood_analysis(X, y):
    # Step 1: Combine X and y for analysis
    inp1 = X.copy()
    inp1['fraud_reported'] = y

    # Step 2: Get categorical columns
    categorical_cols = inp1.select_dtypes(include=['object', 'category']).columns

    # Step 3: Loop through each categorical column
    for col in categorical_cols:
        # Calculate mean target value (likelihood) for each category
        likelihood = inp1.groupby(col)['fraud_reported'].mean().sort_values(ascending=False)

        # Plot the likelihood
        plt.figure(figsize=(8, 3))
        likelihood.plot(kind='bar', color='lightgreen', edgecolor='black')
        plt.title(f'Target Likelihood (fraud_reported=1) for "{col}"')
        plt.xlabel(col)
        plt.ylabel('P(fraud_reported=1)')
        plt.xticks(rotation=45)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
for col in numerical_cols:
    plt.figure(figsize=(5, 4))
    sns.boxplot(x='fraud_reported', y=col, data=df)
    plt.title(f'{col} vs Fraud Reported')
    plt.xlabel('Fraud Reported (0 = No, 1 = Yes)')
    plt.ylabel(col)
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
#pip install imbalanced-learn

#Note:Resampling should be done after splitting the data into training and test sets — and it should be applied only to the training set.
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

# Before resampling
print("Before Resampling:", Counter(y_train))
#print("Before Resampling:", Counter(X_train))
#X_train_encoded = pd.get_dummies(X_train)

# Apply RandomOverSampler
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train)
#X_resampled, y_resampled = ros.fit_resample(X_train_encoded, y_train)
#X_resampled = pd.DataFrame(X_resampled, columns=X_train_encoded.columns)



# After resampling
print("After Resampling:", Counter(y_resampled))
#print("After Resampling:", Counter(X_resampled))
# Out:
# Before Resampling: Counter({False: 253, True: 253})
# After Resampling: Counter({False: 253, True: 253})

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
features_to_drop = [
    'age',                  # Highly correlated with 'months_as_customer'
    'injury_claim',         # Highly correlated with 'total_claim_amount'
    'property_claim',       # Highly correlated with 'total_claim_amount'
    'vehicle_claim',        # Highly correlated with 'total_claim_amount'
    'umbrella_limit',       # Low correlation
    'capital-gains',        # Low correlation
    'policy_deductable',    # Low importance
    'auto_year',
    'policy_bind_date', 
    'incident_date', 
    'incident_location',  
    'incident_hour_of_the_day',
    'insured_hobbies',
    'incident_city'
]


# Drop the redundant columns from resampled training data (X_resampled)
X_train = X_train.drop(columns=features_to_drop, errors='ignore')

# Drop the redundant columns from the validation data (if applicable)
X_val = X_val.drop(columns=features_to_drop, errors='ignore')

# %%
# Check the data

print("Training Data shape after dropping redundant columns:", X_train.shape)
print("Validation Data shape after dropping redundant columns:", X_val.shape)
# Out:
# Training Data shape after dropping redundant columns: (506, 69)
# Validation Data shape after dropping redundant columns: (143, 109)

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information

# Extended sample dataset with more categorical columns
data = {
    'Job_Type': ['Engineer', 'Doctor', 'Lawyer', 'Artist', 'Engineer', 'Doctor',
                 'Scientist', 'Actor', 'Musician', 'Scientist', 'Engineer', 'Artist'],
    'Education_Level': ['Graduate', 'PhD', 'Graduate', 'High School', 'Graduate', 'Graduate',
                        'PhD', 'High School', 'High School', 'PhD', 'Graduate', 'Graduate'],
    'Loan_Status': ['Approved', 'Rejected', 'Approved', 'Rejected', 'Approved', 'Approved',
                    'Rejected', 'Rejected', 'Approved', 'Rejected', 'Approved', 'Rejected'],
    'Marital_Status': ['Single', 'Married', 'Single', 'Divorced', 'Single', 'Married',
                       'Single', 'Widowed', 'Divorced', 'Single', 'Single', 'Married'],
    'Property_Area': ['Urban', 'Rural', 'Urban', 'Semiurban', 'Urban', 'Urban',
                      'Semiurban', 'Rural', 'Semiurban', 'Urban', 'Rural', 'Urban'],
    'Loan_Purpose': ['Education', 'Home', 'Car', 'Business', 'Education', 'Car',
                     'Vacation', 'Education', 'Home', 'Medical', 'Education', 'Home'],
    'Dependents': ['0', '1', '2', '0', '3+', '0', '1', '0', '2', '0', '1', '3+'],
    'Housing_Type': ['Owned', 'Rented', 'Rented', 'Owned', 'Owned', 'Rented',
                     'Owned', 'Rented', 'Rented', 'Owned', 'Owned', 'Rented'],
    'Internet_Access': ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes',
                        'No', 'No', 'Yes', 'No', 'Yes', 'Yes'],
    'Vehicle_Type': ['Car', 'Bike', 'Car', 'None', 'Car', 'None',
                     'Bike', 'Car', 'None', 'Car', 'Bike', 'None']
}

X = pd.DataFrame(data)

# Set the frequency threshold (e.g., 10%)
threshold = 0.10

# Identify categorical columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns

#cat_cols = inp1.select_dtypes(include='object').columns

# Combine infrequent categories
for col in categorical_cols:
    freq = X[col].value_counts(normalize=True)
    common_categories = freq[freq > threshold].index
    X[col + '_Modified'] = X[col].apply(lambda x: x if x in common_categories else 'Other')

# Display the updated DataFrame
print(X)
# Out:
#      Job_Type Education_Level Loan_Status Marital_Status Property_Area  \
# 0    Engineer        Graduate    Approved         Single         Urban
# 1      Doctor             PhD    Rejected        Married         Rural
# 2      Lawyer        Graduate    Approved         Single         Urban
# 3      Artist     High School    Rejected       Divorced     Semiurban
# 4    Engineer        Graduate    Approved         Single         Urban
# 5      Doctor        Graduate    Approved        Married         Urban
# 6   Scientist             PhD    Rejected         Single     Semiurban
# 7       Actor     High School    Rejected        Widowed         Rural
# 8    Musician     High School    Approved       Divorced     Semiurban
# 9   Scientist             PhD    Rejected         Single         Urban
# 10   Engineer        Graduate    Approved         Single         Rural
# 11     Artist        Graduate    Rejected        Married         Urban
#
#    Loan_Purpose Dependents Housing_Type Internet_Access Vehicle_Type  \
# 0     Education          0        Owned             Yes          Car
# 1          Home          1       Rented              No         Bike
# 2           Car          2       Rented             Yes          Car
# 3      Business          0        Owned              No         None
# 4     Education         3+        Owned             Yes          Car
# 5           Car          0       Rented             Yes         None
# 6      Vacation          1        Owned              No         Bike
# 7     Education          0       Rented              No          Car
# 8          Home          2       Rented             Yes         None
# 9       Medical          0        Owned              No          Car
# 10    Education          1        Owned             Yes         Bike
# 11         Home         3+       Rented             Yes         None
#
#    Job_Type_Modified Education_Level_Modified Loan_Status_Modified  \
# 0           Engineer                 Graduate             Approved
# 1             Doctor                      PhD             Rejected
# 2              Other                 Graduate             Approved
# 3             Artist              High School             Rejected
# 4           Engineer                 Graduate             Approved
# 5             Doctor                 Graduate             Approved
# 6          Scientist                      PhD             Rejected
# 7              Other              High School             Rejected
# 8              Other              High School             Approved
# 9          Scientist                      PhD             Rejected
# 10          Engineer                 Graduate             Approved
# 11            Artist                 Graduate             Rejected
#
#    Marital_Status_Modified Property_Area_Modified Loan_Purpose_Modified  \
# 0                   Single                  Urban             Education
# 1                  Married                  Rural                  Home
# 2                   Single                  Urban                   Car
# 3                 Divorced              Semiurban                 Other
# 4                   Single                  Urban             Education
# 5                  Married                  Urban                   Car
# 6                   Single              Semiurban                 Other
# 7                    Other                  Rural             Education
# 8                 Divorced              Semiurban                  Home
# 9                   Single                  Urban                 Other
# 10                  Single                  Rural             Education
# 11                 Married                  Urban                  Home
#
#    Dependents_Modified Housing_Type_Modified Internet_Access_Modified  \
# 0                    0                 Owned                      Yes
# 1                    1                Rented                       No
# 2                    2                Rented                      Yes
# 3                    0                 Owned                       No
# 4                   3+                 Owned                      Yes
# 5                    0                Rented                      Yes
# 6                    1                 Owned                       No
# 7                    0                Rented                       No
# 8                    2                Rented                      Yes
# 9                    0                 Owned                       No
# 10                   1                 Owned                      Yes
# 11                  3+                Rented                      Yes
#
#    Vehicle_Type_Modified
# 0                    Car
# 1                   Bike
# 2                    Car
# 3                   None
# 4                    Car
# 5                   None
# 6                   Bike
# 7                    Car
# 8                   None
# 9                    Car
# 10                  Bike
# 11                  None

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
categorical_cols = ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level',
                    'insured_occupation', 'insured_relationship', 'incident_type', 'collision_type',
                    'incident_severity', 'authorities_contacted', 'incident_state', 'property_damage',
                    'police_report_available', 'auto_make', 'auto_model']

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
#X = inp1.drop(columns='fraud_reported')
#y= inp1['fraud_reported']
#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
# Reset index for all train and test sets
#X_train.reset_index(drop=True, inplace=True)
#X_val.reset_index(drop=True, inplace=True)
#y_train.reset_index(drop=True, inplace=True)
#y_val.reset_index(drop=True, inplace=True)

# Create dummy variables using the 'get_dummies' for categorical columns in training data
X_train= pd.get_dummies(X_train, columns=categorical_cols, drop_first=True)
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1078], line 11
#       1 #X = inp1.drop(columns='fraud_reported')
#       2 #y= inp1['fraud_reported']
#       3 #X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
#    (...)
#       9
#      10 # Create dummy variables using the 'get_dummies' for categorical columns in training data
# ---> 11 X_train= pd.get_dummies(X_train, columns=categorical_cols, drop_first=True)
#      12 X_train.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level',\n       'insured_occupation', 'insured_relationship', 'incident_type',\n       'collision_type', 'incident_severity', 'authorities_contacted',\n       'incident_state', 'property_damage', 'police_report_available',\n       'auto_make', 'auto_model'],\n      dtype='object')] are in the [columns]"

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data

# Create dummy variables in validation data using the same columns as in training data
X_val= pd.get_dummies(X_val, columns=categorical_cols, drop_first=True)
X_val = X_val.reindex(columns=X_train.columns, fill_value=0)

# Check the resulting DataFrame with dummies in validation data
print(X_val.head())

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
y_train = y_train.astype(int)
y_train = pd.get_dummies(y_train, drop_first=True)

# Create dummy variable for dependent feature in validation data
y_val = y_val.astype(int)
y_val = pd.get_dummies(y_val, drop_first=True)

y_train.head()

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Step 1: Fit the scaler on the training data and transform the training features
X_train_scaled = scaler.fit_transform(X_train)

# Step 2: Transform the validation data using the already fitted scaler (no fitting)
X_val_scaled = scaler.transform(X_val)

# Convert back to DataFrames for easier handling
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_val = pd.DataFrame(X_val_scaled, columns=X_val.columns)

# Step 3: Check the first few rows of the scaled data
print("Scaled Training Features (X_train_scaled):")
print(X_train.head())

print("\nScaled Validation Features (X_val_scaled):")
print(X_val.head())

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter


X_train_encoded = pd.get_dummies(X_train)
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X_train_encoded, y_train)
X_resampled = pd.DataFrame(X_resampled, columns=X_train_encoded.columns)


# Apply RFECV to identify the most relevant features


# Reset indices after resampling to avoid issues with index misalignment
y_resampled = pd.Series(y_resampled.values.ravel())

# Step 2: Define the Logistic Regression model
log_reg = LogisticRegression(max_iter=1000, solver='liblinear')

# Step 3: Define RFECV with Stratified K-Fold cross-validation
rfecv = RFECV(
    estimator=log_reg,  # Using Logistic Regression as estimator
    step=1,  # Number of features to remove at each iteration
    cv=StratifiedKFold(5),  # StratifiedKFold for cross-validation (5 folds)
    scoring='accuracy',  # You can use 'roc_auc' for imbalanced classes
    n_jobs=-1  # To speed up the process using all available cores
)

# Step 4: Fit RFECV on the resampled training data
rfecv.fit(X_resampled, y_resampled)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#       estimator=LogisticRegression(max_iter=1000, solver='liblinear'),
#       n_jobs=-1, scoring='accuracy')

# %%
# Display the features ranking by RFECV in a DataFrame
ranking_df = pd.DataFrame({
    'Feature': X_resampled.columns,
    'Ranking': rfecv.ranking_,
    'Selected': rfecv.support_
})

# Display the feature ranking DataFrame
print(ranking_df)
# Out:
#                         Feature  Ranking  Selected
# 0            months_as_customer        1      True
# 1   number_of_vehicles_involved        1      True
# 2            total_claim_amount        1      True
# 3               policy_state_IN        1      True
# 4               policy_state_OH        1      True
# ..                          ...      ...       ...
# 64                auto_model_TL        1      True
# 65             auto_model_Tahoe        1      True
# 66          auto_model_Wrangler        1      True
# 67                auto_model_X5        1      True
# 68                auto_model_X6        1      True
#
# [69 rows x 3 columns]

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = X_resampled.columns[rfecv.support_]
print("\nSelected columns:", col)
# Out:
# Selected columns: Index(['months_as_customer', 'number_of_vehicles_involved',
#        'total_claim_amount', 'policy_state_IN', 'policy_state_OH',
#        'policy_csl_500/1000', 'insured_sex_MALE',
#        'insured_education_level_College', 'insured_education_level_JD',
#        'insured_education_level_MD', 'insured_occupation_armed-forces',
#        'insured_occupation_craft-repair', 'insured_occupation_exec-managerial',
#        'insured_occupation_farming-fishing',
#        'insured_occupation_handlers-cleaners',
#        'insured_occupation_machine-op-inspct',
#        'insured_occupation_priv-house-serv',
#        'insured_relationship_not-in-family',
#        'insured_relationship_other-relative', 'insured_relationship_own-child',
#        'insured_relationship_unmarried', 'insured_relationship_wife',
#        'incident_type_Parked Car', 'incident_type_Vehicle Theft',
#        'collision_type_Front Collision', 'collision_type_Rear Collision',
#        'collision_type_Side Collision', 'incident_severity_Minor Damage',
#        'incident_severity_Total Loss', 'incident_severity_Trivial Damage',
#        'authorities_contacted_Fire', 'authorities_contacted_Other',
#        'authorities_contacted_Police', 'authorities_contacted_Unknown',
#        'incident_state_NY', 'incident_state_OH', 'incident_state_WV',
#        'property_damage_NO', 'property_damage_YES',
#        'police_report_available_NO', 'auto_make_BMW', 'auto_make_Ford',
#        'auto_make_Mercedes', 'auto_make_Suburu', 'auto_model_92x',
#        'auto_model_A3', 'auto_model_C300', 'auto_model_Camry',
#        'auto_model_Civic', 'auto_model_E400', 'auto_model_Escape',
#        'auto_model_Fusion', 'auto_model_Grand Cherokee',
#        'auto_model_Highlander', 'auto_model_Impreza', 'auto_model_Legacy',
#        'auto_model_M5', 'auto_model_Malibu', 'auto_model_Maxima',
#        'auto_model_Neon', 'auto_model_Passat', 'auto_model_Pathfinder',
#        'auto_model_RAM', 'auto_model_Silverado', 'auto_model_TL',
#        'auto_model_Tahoe', 'auto_model_Wrangler', 'auto_model_X5',
#        'auto_model_X6'],
#       dtype='object')

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
X_selected = X_resampled[col]

# %%
# Import statsmodels and add constant
import statsmodels.api as sm

# Step 1: Reset index for both X and y
X_selected = X_selected.reset_index(drop=True)
y_resampled = y_resampled.reset_index(drop=True)

# Step 2: Add constant AFTER resetting the index
X_train = sm.add_constant(X_selected)
y_train= y_resampled

# Step 3: Make sure X and y still aligned
print(X_train.shape)
print(y_train.shape)
# Out:
# (506, 70)
# (506,)

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Check for constant columns
constant_columns = [col for col in X_train.columns if X_train[col].nunique() == 1]
print(f"Constant Columns: {constant_columns}")

# Remove constant columns
X_train = X_train.drop(columns=constant_columns)

# Fit a logistic Regression model on X_train after adding a constant and output the summary
log_reg_model = sm.Logit(y_train, X_train)
log_reg_result = log_reg_model.fit()
log_reg_result.summary()
# Out:
# Constant Columns: ['const']
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.347425
#          Iterations: 35
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  506
# Model:                          Logit   Df Residuals:                      438
# Method:                           MLE   Df Model:                           67
# Date:                Wed, 21 May 2025   Pseudo R-squ.:                  0.4988
# Time:                        19:14:16   Log-Likelihood:                -175.80
# converged:                      False   LL-Null:                       -350.73
# Covariance Type:            nonrobust   LLR p-value:                 6.773e-40
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# months_as_customer                      -0.1923      0.157     -1.225      0.221      -0.500       0.115
# number_of_vehicles_involved             -0.2542      0.176     -1.447      0.148      -0.599       0.090
# total_claim_amount                      -0.2456      0.304     -0.807      0.420      -0.842       0.351
# policy_state_IN                          0.2153      0.178      1.211      0.226      -0.133       0.564
# policy_state_OH                          0.2134      0.176      1.214      0.225      -0.131       0.558
# policy_csl_500/1000                      0.4229      0.166      2.546      0.011       0.097       0.748
# insured_sex_MALE                         0.1179      0.161      0.734      0.463      -0.197       0.433
# insured_education_level_College         -0.2527      0.171     -1.480      0.139      -0.587       0.082
# insured_education_level_JD               0.5052      0.162      3.124      0.002       0.188       0.822
# insured_education_level_MD               0.5272      0.152      3.457      0.001       0.228       0.826
# insured_occupation_armed-forces          0.1354      0.148      0.912      0.362      -0.155       0.426
# insured_occupation_craft-repair         -0.1897      0.167     -1.135      0.256      -0.517       0.138
# insured_occupation_exec-managerial       0.2691      0.157      1.718      0.086      -0.038       0.576
# insured_occupation_farming-fishing       0.0924      0.173      0.534      0.593      -0.247       0.432
# insured_occupation_handlers-cleaners    -0.4937      0.194     -2.547      0.011      -0.874      -0.114
# insured_occupation_machine-op-inspct    -0.2433      0.163     -1.490      0.136      -0.563       0.077
# insured_occupation_priv-house-serv      -0.2852      0.167     -1.709      0.087      -0.612       0.042
# insured_relationship_not-in-family      -0.0479      0.198     -0.242      0.809      -0.435       0.340
# insured_relationship_other-relative      0.1700      0.200      0.849      0.396      -0.222       0.563
# insured_relationship_own-child          -0.2888      0.208     -1.388      0.165      -0.697       0.119
# insured_relationship_unmarried           0.4312      0.200      2.155      0.031       0.039       0.823
# insured_relationship_wife                0.2428      0.183      1.330      0.183      -0.115       0.601
# incident_type_Parked Car                -0.3037   3.44e+06  -8.82e-08      1.000   -6.75e+06    6.75e+06
# incident_type_Vehicle Theft             -0.2406   4.05e+06  -5.93e-08      1.000   -7.95e+06    7.95e+06
# collision_type_Front Collision           0.1959   5.08e+06   3.86e-08      1.000   -9.96e+06    9.96e+06
# collision_type_Rear Collision            0.3379   5.82e+06    5.8e-08      1.000   -1.14e+07    1.14e+07
# collision_type_Side Collision           -0.1661   5.67e+06  -2.93e-08      1.000   -1.11e+07    1.11e+07
# incident_severity_Minor Damage          -1.6456      0.223     -7.394      0.000      -2.082      -1.209
# incident_severity_Total Loss            -1.6013      0.211     -7.592      0.000      -2.015      -1.188
# incident_severity_Trivial Damage        -1.3195      0.293     -4.505      0.000      -1.894      -0.745
# authorities_contacted_Fire              -0.2461      0.213     -1.155      0.248      -0.664       0.171
# authorities_contacted_Other              0.1029      0.196      0.524      0.600      -0.282       0.488
# authorities_contacted_Police             0.2708      0.225      1.202      0.230      -0.171       0.712
# authorities_contacted_Unknown           -0.1656      0.274     -0.604      0.546      -0.703       0.372
# incident_state_NY                       -0.3936      0.168     -2.344      0.019      -0.723      -0.064
# incident_state_OH                       -0.2041      0.191     -1.070      0.285      -0.578       0.170
# incident_state_WV                       -0.3697      0.173     -2.141      0.032      -0.708      -0.031
# property_damage_NO                      -0.3185      0.180     -1.769      0.077      -0.671       0.034
# property_damage_YES                     -0.0914      0.178     -0.514      0.607      -0.440       0.257
# police_report_available_NO               0.4199      0.168      2.503      0.012       0.091       0.749
# auto_make_BMW                           -0.2489      0.286     -0.869      0.385      -0.810       0.313
# auto_make_Ford                           0.1717      0.207      0.828      0.408      -0.235       0.578
# auto_make_Mercedes                       0.2255      0.269      0.838      0.402      -0.302       0.753
# auto_make_Suburu                         0.1312      0.252      0.521      0.602      -0.362       0.624
# auto_model_92x                           0.3557      0.155      2.296      0.022       0.052       0.659
# auto_model_A3                            0.2829      0.151      1.876      0.061      -0.013       0.578
# auto_model_C300                         -0.2000      0.220     -0.911      0.362      -0.630       0.230
# auto_model_Camry                         0.0202      0.186      0.108      0.914      -0.345       0.385
# auto_model_Civic                         0.3736      0.137      2.719      0.007       0.104       0.643
# auto_model_E400                          0.4049      0.312      1.298      0.194      -0.206       1.016
# auto_model_Escape                        0.4626      0.207      2.235      0.025       0.057       0.868
# auto_model_Fusion                       -0.1005      0.155     -0.649      0.516      -0.404       0.203
# auto_model_Grand Cherokee                0.0266      0.132      0.202      0.840      -0.231       0.285
# auto_model_Highlander                    0.1603      0.145      1.109      0.267      -0.123       0.444
# auto_model_Impreza                       0.1276      0.198      0.646      0.518      -0.260       0.515
# auto_model_Legacy                        0.0695      0.197      0.352      0.725      -0.318       0.457
# auto_model_M5                            0.5029      0.232      2.165      0.030       0.048       0.958
# auto_model_Malibu                       -0.1543      0.185     -0.833      0.405      -0.517       0.209
# auto_model_Maxima                        0.1684      0.148      1.138      0.255      -0.122       0.458
# auto_model_Neon                          0.0330      0.148      0.224      0.823      -0.256       0.322
# auto_model_Passat                        0.0859      0.156      0.552      0.581      -0.219       0.391
# auto_model_Pathfinder                   -0.1727      0.215     -0.801      0.423      -0.595       0.250
# auto_model_RAM                          -0.1341      0.161     -0.833      0.405      -0.450       0.181
# auto_model_Silverado                     0.4437      0.184      2.417      0.016       0.084       0.803
# auto_model_TL                           -0.3172      0.180     -1.763      0.078      -0.670       0.035
# auto_model_Tahoe                         0.0226      0.191      0.119      0.905      -0.351       0.396
# auto_model_Wrangler                     -0.1197      0.167     -0.716      0.474      -0.447       0.208
# auto_model_X5                            0.3338      0.184      1.812      0.070      -0.027       0.695
# auto_model_X6                            0.4273      0.174      2.449      0.014       0.085       0.769
# ========================================================================================================
# """

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
# Compute VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X_train.columns  # Use the appropriate dataframe
vif_data["VIF"] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]

# Display VIF values
print(vif_data)
# Out:
#                         Feature       VIF
# 0            months_as_customer  1.382511
# 1   number_of_vehicles_involved  1.552723
# 2            total_claim_amount  4.536237
# 3               policy_state_IN  1.962818
# 4               policy_state_OH  1.674425
# ..                          ...       ...
# 64                auto_model_TL  1.142867
# 65             auto_model_Tahoe  1.542718
# 66          auto_model_Wrangler  1.242889
# 67                auto_model_X5  2.080471
# 68                auto_model_X6  1.962052
#
# [69 rows x 2 columns]

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %%
# Identifying features to drop based on p-values greater than 0.05
# Extract p-values from the model result
p_values = log_reg_result.pvalues

# Identify features with p-values greater than 0.05
high_p_value_features = p_values[p_values > 0.05].index.tolist()

# Drop the high p-value features from X_train
X_train_dropped = X_train.drop(columns=high_p_value_features)

# Re-fit the model without the high p-value features
log_reg_model_dropped = sm.Logit(y_train, X_train_dropped)
log_reg_result_dropped = log_reg_model_dropped.fit()

# Display the summary of the new model
log_reg_result_dropped.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.433676
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  506
# Model:                          Logit   Df Residuals:                      489
# Method:                           MLE   Df Model:                           16
# Date:                Wed, 21 May 2025   Pseudo R-squ.:                  0.3743
# Time:                        19:14:17   Log-Likelihood:                -219.44
# converged:                       True   LL-Null:                       -350.73
# Covariance Type:            nonrobust   LLR p-value:                 1.347e-46
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# policy_csl_500/1000                      0.2251      0.126      1.790      0.073      -0.021       0.472
# insured_education_level_JD               0.4573      0.122      3.733      0.000       0.217       0.697
# insured_education_level_MD               0.5575      0.116      4.803      0.000       0.330       0.785
# insured_occupation_handlers-cleaners    -0.4454      0.162     -2.744      0.006      -0.764      -0.127
# insured_relationship_unmarried           0.3333      0.120      2.788      0.005       0.099       0.568
# incident_severity_Minor Damage          -1.4459      0.158     -9.163      0.000      -1.755      -1.137
# incident_severity_Total Loss            -1.2779      0.152     -8.414      0.000      -1.576      -0.980
# incident_severity_Trivial Damage        -1.2824      0.164     -7.838      0.000      -1.603      -0.962
# incident_state_NY                       -0.2836      0.127     -2.226      0.026      -0.533      -0.034
# incident_state_WV                       -0.3897      0.136     -2.855      0.004      -0.657      -0.122
# police_report_available_NO               0.2451      0.125      1.954      0.051      -0.001       0.491
# auto_model_92x                           0.2139      0.114      1.880      0.060      -0.009       0.437
# auto_model_Civic                         0.3018      0.099      3.060      0.002       0.109       0.495
# auto_model_Escape                        0.4127      0.135      3.059      0.002       0.148       0.677
# auto_model_M5                            0.4315      0.146      2.957      0.003       0.145       0.718
# auto_model_Silverado                     0.2893      0.149      1.936      0.053      -0.004       0.582
# auto_model_X6                            0.1564      0.099      1.573      0.116      -0.038       0.351
# ========================================================================================================
# """

# %%
# Calculate VIF for the remaining features
vif_dropped = pd.DataFrame()
vif_dropped["Feature"] = X_train_dropped.columns
vif_dropped["VIF"] = [variance_inflation_factor(X_train_dropped.values, i) for i in range(X_train_dropped.shape[1])]
print(vif_dropped)
# Out:
#                                  Feature       VIF
# 0                    policy_csl_500/1000  1.053514
# 1             insured_education_level_JD  1.109782
# 2             insured_education_level_MD  1.204888
# 3   insured_occupation_handlers-cleaners  1.114518
# 4         insured_relationship_unmarried  1.070347
# 5         incident_severity_Minor Damage  1.325212
# 6           incident_severity_Total Loss  1.202103
# 7       incident_severity_Trivial Damage  1.121964
# 8                      incident_state_NY  1.172452
# 9                      incident_state_WV  1.141325
# 10            police_report_available_NO  1.084271
# 11                        auto_model_92x  1.060321
# 12                      auto_model_Civic  1.201041
# 13                     auto_model_Escape  1.113245
# 14                         auto_model_M5  1.046968
# 15                  auto_model_Silverado  1.033885
# 16                         auto_model_X6  1.034130

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data
y_train_pred = log_reg_result.predict(X_train)
print(y_train_pred)


# Reshape it into an array
y_train_pred_reshaped = y_train_pred.values.reshape(-1, 1)
# Out:
# 0      0.866439
# 1      0.947579
# 2      0.058090
# 3      0.952992
# 4      0.378661
#          ...
# 501    0.952992
# 502    0.876391
# 503    0.986044
# 504    0.944770
# 505    0.952992
# Length: 506, dtype: float64

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model
y_train_pred_array = y_train_pred.to_numpy()

# Now, create a DataFrame containing the actual fraud reported flag and the predicted probabilities
results_df = pd.DataFrame({
    'Actual': y_train,  # Actual fraud flag (0 or 1)
    'Predicted_Probabilities': y_train_pred_array  # Predicted probabilities
})

# Create new column indicating predicted classifications based on a cutoff value of 0.5
results_df['Predicted_Class'] = (results_df['Predicted_Probabilities'] >= 0.5).astype(int)

# View the results
results_df.head()
# Out:
#    Actual  Predicted_Probabilities  Predicted_Class
# 0   False                 0.866439                1
# 1    True                 0.947579                1
# 2   False                 0.058090                0
# 3    True                 0.952992                1
# 4   False                 0.378661                0

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.
#
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the mode

# Step 1: Calculate the accuracy of the model
accuracy = metrics.accuracy_score(results_df['Actual'], results_df['Predicted_Class'])
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8300395256916996

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
conf_matrix = metrics.confusion_matrix(results_df['Actual'], results_df['Predicted_Class'])
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[171  82]
#  [  4 249]]

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
# Calculate confusion matrix
cm = confusion_matrix(results_df['Actual'], results_df['Predicted_Class'])
TN, FP, FN, TP = cm.ravel()

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = TP / (TP + FN)
print(f"Sensitivity: {sensitivity:.2f}")


# Calculate the specificity
specificity = TN / (TN + FP)
print(f"Specificity: {specificity:.2f}")


# Calculate Precision
precision = metrics.precision_score(results_df['Actual'], results_df['Predicted_Class'])
print(f"Precision: {precision}")



# Calculate Recall
recall = metrics.recall_score(results_df['Actual'], results_df['Predicted_Class'])
print(f"Recall: {recall}")


# Calculate F1 Score
f1 = metrics.f1_score(results_df['Actual'], results_df['Predicted_Class'])
print(f"F1-Score: {f1}")
# Out:
# Sensitivity: 0.98
# Specificity: 0.68
# Precision: 0.7522658610271903
# Recall: 0.9841897233201581
# F1-Score: 0.8527397260273972

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
from sklearn.metrics import roc_curve, roc_auc_score
    
y_true = results_df['Actual']
y_pred_probs = results_df['Predicted_Probabilities']


# Define ROC function

def plot_roc_curve(y_true, y_pred_probs):
    """
    Plots the ROC Curve and prints the AUC score.

    Parameters:
    - y_true: list or array of actual class labels (0 or 1)
    - y_pred_probs: list or array of predicted probabilities for the positive class
    """
    y_true = results_df['Actual']
    y_pred_probs = results_df['Predicted_Probabilities']

    # Step 1: Compute FPR, TPR, thresholds
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_probs)

    # Step 2: Compute AUC
    auc_score = roc_auc_score(y_true, y_pred_probs)

    # Step 3: Plot ROC Curve
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', label=f'ROC Curve (AUC = {auc_score:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

    # Optional: return AUC if needed
    return auc_score

# %%
# Call the ROC function
plot_roc_curve(y_train, y_train_pred)
# Out:
# 0.9693793060350888

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
cutoff_values = [0.3, 0.4, 0.5, 0.6, 0.7]
for cutoff in cutoff_values:
    col_name = f'Predicted_Class_{cutoff}'
    results_df[col_name] = (results_df['Predicted_Probabilities'] >= cutoff).astype(int)

results_df
# Out:
#      Actual  Predicted_Probabilities  Predicted_Class  Predicted_Class_0.3  \
# 0     False                 0.866439                1                    1
# 1      True                 0.947579                1                    1
# 2     False                 0.058090                0                    0
# 3      True                 0.952992                1                    1
# 4     False                 0.378661                0                    1
# ..      ...                      ...              ...                  ...
# 501    True                 0.952992                1                    1
# 502    True                 0.876391                1                    1
# 503    True                 0.986044                1                    1
# 504    True                 0.944770                1                    1
# 505    True                 0.952992                1                    1
#
#      Predicted_Class_0.4  Predicted_Class_0.5  Predicted_Class_0.6  \
# 0                      1                    1                    1
# 1                      1                    1                    1
# 2                      0                    0                    0
# 3                      1                    1                    1
# 4                      0                    0                    0
# ..                   ...                  ...                  ...
# 501                    1                    1                    1
# 502                    1                    1                    1
# 503                    1                    1                    1
# 504                    1                    1                    1
# 505                    1                    1                    1
#
#      Predicted_Class_0.7
# 0                      1
# 1                      1
# 2                      0
# 3                      1
# 4                      0
# ..                   ...
# 501                    1
# 502                    1
# 503                    1
# 504                    1
# 505                    1
#
# [506 rows x 8 columns]

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
results = []
metrics_df = pd.DataFrame(results)
cutoff_values = [0.3, 0.4, 0.5, 0.6, 0.7]

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
for cutoff in cutoff_values:
    
    # Predict class based on cutoff
    results_df['Predicted_Class'] = (results_df['Predicted_Probabilities'] >= cutoff).astype(int)

    # Confusion matrix
    tn, fp, fn, tp = confusion_matrix(results_df['Actual'], results_df['Predicted_Class']).ravel()

    # Calculate metrics
    accuracy = metrics.accuracy_score(results_df['Actual'], results_df['Predicted_Class'])

    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0

    # Save results
    results.append({
        'Cutoff': cutoff,
        'Accuracy': round(accuracy, 2),
        'Sensitivity': round(sensitivity, 2),
        'Specificity': round(specificity, 2)
    })

# Create a DataFrame from the results
metrics_df = pd.DataFrame(results)

# Plot the metrics against cutoff values
plt.figure(figsize=(10, 6))

plt.plot(metrics_df['Cutoff'], metrics_df['Accuracy'], label='Accuracy', marker='o')
plt.plot(metrics_df['Cutoff'], metrics_df['Sensitivity'], label='Sensitivity', marker='o')
plt.plot(metrics_df['Cutoff'], metrics_df['Specificity'], label='Specificity', marker='o')

plt.xlabel('Probability Cutoff')
plt.ylabel('Metric Value')
plt.title('Performance Metrics at Different Cutoff Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
# Use the optimal cutoff = 0.3
optimal_cutoff = 0.3

# Create the final prediction column
results_df['Final_Prediction'] = (results_df['Predicted_Probabilities'] >= optimal_cutoff).astype(int)

# View the updated DataFrame
results_df[['Actual', 'Predicted_Probabilities', 'Final_Prediction']].head()
# Out:
#    Actual  Predicted_Probabilities  Final_Prediction
# 0   False                 0.866439                 1
# 1    True                 0.947579                 1
# 2   False                 0.058090                 0
# 3    True                 0.952992                 1
# 4   False                 0.378661                 1

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
from sklearn.metrics import accuracy_score

# Check the accuracy now
final_accuracy = accuracy_score(results_df['Actual'], results_df['Final_Prediction'])

# Print the result
print(f"Accuracy using optimal cutoff (0.3): {round(final_accuracy, 4)}")
# Out:
# Accuracy using optimal cutoff (0.3): 0.7391

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
from sklearn.metrics import confusion_matrix

# Create confusion matrix
cm = confusion_matrix(results_df['Actual'], results_df['Final_Prediction'])

# Display the confusion matrix
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[124 129]
#  [  3 250]]

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = cm.ravel()
print(f"\nTrue Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives: {tp}")
# Out:
# True Negatives: 124
# False Positives: 129
# False Negatives: 3
# True Positives: 250

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print(f"Sensitivity (Recall): {round(sensitivity, 4)}")

# Calculate the specificity
specificity = tn / (tn + fp)
print(f"Specificity: {round(specificity, 4)}")

# Calculate Precision
precision = tp / (tp + fp)
print(f"Precision: {round(precision, 4)}")

# Calculate Recall
sensitivity = tp / (tp + fn)
print(f"Sensitivity (Recall): {round(sensitivity, 4)}")

# Calculate F1 Score
f1_score = 2 * (precision * sensitivity) / (precision + sensitivity)
print(f"F1 Score: {round(f1_score, 4)}")
# Out:
# Sensitivity (Recall): 0.9881
# Specificity: 0.4901
# Precision: 0.6596
# Sensitivity (Recall): 0.9881
# F1 Score: 0.7911

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
y_true = results_df['Actual']
y_scores = results_df['Predicted_Probabilities']

precision, recall, thresholds = precision_recall_curve(y_true, y_scores)

# Plotting precision and recall vs thresholds
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precision[:-1], label='Precision', color='blue', marker='o')
plt.plot(thresholds, recall[:-1], label='Recall', color='green', marker='x')
plt.xlabel('Probability Threshold')
plt.ylabel('Score')
plt.title('Precision-Recall Tradeoff')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_resampled, y_resampled)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
# Create a DataFrame to visualise the importance scores
importance_df = pd.DataFrame({
    'Feature': X_resampled.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#                            Feature  Importance
# 2               total_claim_amount    0.112432
# 0               months_as_customer    0.090305
# 27  incident_severity_Minor Damage    0.071523
# 28    incident_severity_Total Loss    0.056691
# 9       insured_education_level_MD    0.029678
# ..                             ...         ...
# 67                   auto_model_X5    0.002848
# 53           auto_model_Highlander    0.002662
# 51               auto_model_Fusion    0.002621
# 58               auto_model_Maxima    0.002434
# 54              auto_model_Impreza    0.002274
#
# [69 rows x 2 columns]

# %%
# Select features with high importance scores
selected_features = importance_df[importance_df['Importance'] > 0.01]['Feature']

# Create a new training data with only the selected features
X_resampled_selected = X_resampled[selected_features]

# X_val is missing some of the selected_features, aligning it using below
X_val_aligned = X_val.reindex(columns=X_resampled.columns, fill_value=0)
X_val_selected = X_val_aligned[selected_features]

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_resampled_selected, y_resampled)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_pred = rf_model.predict(X_resampled_selected)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
train_accuracy = accuracy_score(y_resampled, y_train_pred)
print(f"Training Accuracy: {train_accuracy:.4f}")
# Out:
# Training Accuracy: 1.0000

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
cm = confusion_matrix(y_resampled, y_train_pred)
print(cm)
# Out:
# [[253   0]
#  [  0 253]]

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = cm.ravel()

print(f"True Positive (TP): {tp}")
print(f"True Negative (TN): {tn}")
print(f"False Positive (FP): {fp}")
print(f"False Negative (FN): {fn}")
# Out:
# True Positive (TP): 253
# True Negative (TN): 253
# False Positive (FP): 0
# False Negative (FN): 0

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)


# Calculate the specificity
specificity = tn / (tn + fp)


# Calculate Precision
precision = tp / (tp + fp)


# Calculate Recall
recall = sensitivity


# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)


print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sensitivity (Recall): 1.0000
# Specificity: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
from sklearn.model_selection import cross_val_score

# Use cross validation to check if the model is overfitting
cv_scores = cross_val_score(rf_model, X_resampled_selected, y_resampled, cv=5, scoring='accuracy')

print(f"Cross-validation accuracy scores: {cv_scores}")
print(f"Mean CV accuracy: {np.mean(cv_scores):.4f}")
print(f"Standard deviation of CV accuracy: {np.std(cv_scores):.4f}")
# Out:
# Cross-validation accuracy scores: [0.92156863 0.89108911 0.97029703 0.96039604 0.89108911]
# Mean CV accuracy: 0.9269
# Standard deviation of CV accuracy: 0.0335

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
from sklearn.model_selection import GridSearchCV

# Use grid search to find the best hyperparamter values
# Initialize the Random Forest model
rf_model = RandomForestClassifier(random_state=42)

# Define the hyperparameter grid to search
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2']
}

# Setup GridSearchCV
grid_search = GridSearchCV(
    estimator=rf_model,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=2
)

# Fit GridSearchCV on training data with selected features
grid_search.fit(X_resampled_selected, y_resampled)

# Print best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best Hyperparameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
# Build the final model using those hyperparameters
final_rf_model = RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    max_features='log2',
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42
)
# Fit the model to the resampled training data with selected features
final_rf_model.fit(X_resampled_selected, y_resampled)
# Out:
# RandomForestClassifier(max_depth=10, max_features='log2', n_estimators=300,
#                        random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data

y_train_pred = final_rf_model.predict(X_resampled_selected)

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
train_accuracy = accuracy_score(y_resampled, y_train_pred)
print(f"Training Accuracy of Random Forest Model: {train_accuracy:.4f}")
# Out:
# Training Accuracy of Random Forest Model: 0.9901

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix = confusion_matrix(y_resampled, y_train_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[248   5]
#  [  0 253]]

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix.ravel()

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)


# Calculate the specificity
specificity = tn / (tn + fp)


# Calculate Precision
precision = tp / (tp + fp)


# Calculate Recall
recall = sensitivity


# Calculate F1-Score
f1_score = 2 * (precision * recall) / (precision + recall)

print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sensitivity (Recall): 1.0000
# Specificity: 0.9802
# Precision: 0.9806
# Recall: 1.0000
# F1 Score: 0.9902

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
final_features = X_train_dropped.columns

if 'const' in final_features:
    final_features_no_const = final_features.drop('const')
else:
    final_features_no_const = final_features

X_val_selected = X_val.reindex(columns=final_features_no_const, fill_value=0)
X_val_selected_const = sm.add_constant(X_val_selected)

print("X_val_selected_const shape:", X_val_selected_const.shape)
print("Model params shape:", log_reg_result_dropped.params.shape)
print(log_reg_result_dropped.params.index)  # See if 'const' is in model params index
# Out:
# X_val_selected_const shape: (143, 18)
# Model params shape: (17,)
# Index(['policy_csl_500/1000', 'insured_education_level_JD',
#        'insured_education_level_MD', 'insured_occupation_handlers-cleaners',
#        'insured_relationship_unmarried', 'incident_severity_Minor Damage',
#        'incident_severity_Total Loss', 'incident_severity_Trivial Damage',
#        'incident_state_NY', 'incident_state_WV', 'police_report_available_NO',
#        'auto_model_92x', 'auto_model_Civic', 'auto_model_Escape',
#        'auto_model_M5', 'auto_model_Silverado', 'auto_model_X6'],
#       dtype='object')

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
# Make predictions on the validation data (probabilities)
y_val_pred_prob = log_reg_result_dropped.predict(X_val_selected)

# Set cutoff for classification
optimal_cutoff = 0.3

# Convert probabilities to class labels (0 or 1) based on cutoff
y_validation_pred = (y_val_pred_prob >= optimal_cutoff).astype(int)

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
# Convert predictions to numpy array and flatten if needed
# Flatten predicted class array if needed
y_validation_pred_array = y_validation_pred.values if hasattr(y_validation_pred, 'values') else y_validation_pred
if y_validation_pred_array.ndim == 2 and y_validation_pred_array.shape[1] == 1:
    y_validation_pred_array = y_validation_pred_array.flatten()

# Flatten actual values if needed
y_val_array = y_val.values if hasattr(y_val, 'values') else y_val
if y_val_array.ndim == 2 and y_val_array.shape[1] == 1:
    y_val_array = y_val_array.flatten()

# Create DataFrame
results_df = pd.DataFrame({
    'Actual': y_val_array,
    'Predicted_Class': y_validation_pred_array
})

results_df.head()

results_df['Actual'] = results_df['Actual'].astype(int)
results_df.head()
# Out:
#    Actual  Predicted_Class
# 0       0                0
# 1       1                1
# 2       0                1
# 3       1                1
# 4       0                1

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
# 1. Predict probabilities on validation data
y_val_pred_prob = log_reg_result_dropped.predict(X_val_selected)

# 2. Define cutoff for classification
optimal_cutoff = 0.3

# 3. Convert probabilities to binary class labels based on cutoff
y_validation_pred = (y_val_pred_prob >= optimal_cutoff).astype(int)

# 4. Prepare arrays and flatten if needed
y_validation_pred_array = y_validation_pred.values if hasattr(y_validation_pred, 'values') else y_validation_pred
if y_validation_pred_array.ndim == 2 and y_validation_pred_array.shape[1] == 1:
    y_validation_pred_array = y_validation_pred_array.flatten()

y_val_array = y_val.values if hasattr(y_val, 'values') else y_val
if y_val_array.ndim == 2 and y_val_array.shape[1] == 1:
    y_val_array = y_val_array.flatten()

# 5. Create final results DataFrame with integer types
results_df = pd.DataFrame({
    'Actual': y_val_array.astype(int),
    'Predicted_Class': y_validation_pred_array.astype(int)
})

# 6. View the first few rows
print(results_df.head())
# Out:
#    Actual  Predicted_Class
# 0       0                0
# 1       1                1
# 2       0                1
# 3       1                1
# 4       0                1

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
accuracy = accuracy_score(y_val_array, y_validation_pred_array)

print(f"Validation Accuracy: {accuracy:.4f}")
# Out:
# Validation Accuracy: 0.5455

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
cm = confusion_matrix(y_val_array, y_validation_pred_array)
print(cm)
# Out:
# [[49 60]
#  [ 5 29]]

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = cm.ravel()

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Sensitivity (Recall, True Positive Rate)
sensitivity = tp / (tp + fn)

# Specificity (True Negative Rate)
specificity = tn / (tn + fp)

# Precision (Positive Predictive Value)
precision = tp / (tp + fp)

# Recall (same as Sensitivity)
recall = sensitivity

# F1 Score (harmonic mean of precision and recall)
f1_score = 2 * (precision * recall) / (precision + recall)

print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sensitivity (Recall): 0.8529
# Specificity: 0.4495
# Precision: 0.3258
# Recall: 0.8529
# F1 Score: 0.4715

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Train model on all features
rf_model_all = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model_all.fit(X_resampled, y_resampled)

# Align validation data to training features
X_val_aligned_all = X_val.reindex(columns=X_resampled.columns, fill_value=0)

# Make predictions
y_val_pred_all = rf_model_all.predict(X_val_aligned_all)

# Optional: Probabilities
# y_val_proba_all = rf_model_all.predict_proba(X_val_aligned_all)[:, 1]

print("Validation Predictions (All Features):")
print(y_val_pred_all)

# Step 1: Get feature importances and select important features
importance_df = pd.DataFrame({
    'Feature': X_resampled.columns,
    'Importance': rf_model_all.feature_importances_
}).sort_values(by='Importance', ascending=False)

selected_features = importance_df[importance_df['Importance'] > 0.01]['Feature']

# Step 2: Prepare data with selected features
X_resampled_selected = X_resampled[selected_features]
X_val_selected = X_val.reindex(columns=selected_features, fill_value=0)

# Step 3: Retrain model on selected features
rf_model_selected = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model_selected.fit(X_resampled_selected, y_resampled)

# Step 4: Predict on validation data
y_val_pred_selected = rf_model_selected.predict(X_val_selected)

print("Validation Predictions (Selected Features):")
print(y_val_pred_selected)
# Out:
# Validation Predictions (All Features):
# [False  True  True  True  True False  True False False False False False
#   True False  True  True False False False False False  True False False
#  False False False  True False False False False  True False False False
#  False False  True False  True False False  True False  True False  True
#  False False  True False False False  True False False False  True  True
#  False False False  True False False False False False False False False
#  False False False False False False False False False False False False
#  False  True False False False False  True False False False False False
#  False False False False  True False  True False False False False  True
#  False False False  True  True False False False False False False False
#  False False False False False  True False False False False False False
#  False False False False False False False False False False False]
# Validation Predictions (Selected Features):
# [False  True False  True  True False  True False False False False  True
#   True False  True  True False False False False False  True False False
#   True False False  True False False False False False False False False
#  False  True False False  True False False  True False  True False  True
#  False False  True False False False  True False False False False  True
#  False  True False  True False False False False False False False False
#  False False False False False False False False False False False False
#  False  True False False False False  True False  True False False False
#  False False  True False  True False False False False False False  True
#  False False False  True  True False False False False False False False
#  False False False False False  True False False False False False False
#  False False False False False False False False False False False]

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
accuracy_all = accuracy_score(y_val, y_val_pred_all)
print(f"Accuracy (All Features): {accuracy_all:.4f}")
# Out:
# Accuracy (All Features): 0.7692

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
cm_all = confusion_matrix(y_val, y_val_pred_all)

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = cm.ravel()

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate Sensitivity
sensitivity = tp / (tp + fn)
print(f"Sensitivity (Recall): {sensitivity:.4f}")

# Calculate Specificity
specificity = tn / (tn + fp)
print(f"Specificity: {specificity:.4f}")


# Calculate Precision

precision = tp / (tp + fp)
print(f"Precision: {precision:.4f}")
# Calculate Recall
recall = sensitivity
print(f"Recall: {recall:.4f}")

# Calculate F1-score
f1_score = 2 * (precision * recall) / (precision + recall)
print(f"F1-score: {f1_score:.4f}")
# Out:
# Sensitivity (Recall): 0.8529
# Specificity: 0.4495
# Precision: 0.3258
# Recall: 0.8529
# F1-score: 0.4715

# %% [markdown]
# ## **Evaluation and Conclusion**
# - Higher loan amounts and lower income are associated with higher default rates.
# - Applicants with 'debt_consolidation' and 'small_business' purposes showed higher defaults.
# - Logistic Regression provided a good baseline but Random Forest outperformed with better AUC and recal
# - - Reject loans with DTI > 30%, interest rate > 20%, or income < ₹40K unless secured..

# %%
]
